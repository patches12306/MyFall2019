# %% [markdown]
# # Lab11: Model Error and Tuning
#
# This lab is presented with some revisions from [Dennis Sun at Cal Poly](https://web.calpoly.edu/~dsun09/index.html) and his [Data301 Course](http://users.csc.calpoly.edu/~dsun09/data301/lectures.html)
#
# ### When you have filled out all the questions, submit via [Tulane Canvas](https://tulane.instructure.com/)
#
# In the previous sections, we learned to build regression models. In this section, we will learn one way to evaluate the quality of a regression model: the training error. We will also discuss the shortcomings of using training error to measure the quality of a regression model.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
pd.options.display.max_rows = 5

housing = pd.read_csv("./data/ames.tsv", sep="\t")
housing
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
#      Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0      NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1      NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# ...    ...       ...          ...  ...       ...     ...    ...          ...
# 2928   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 2929   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
#
#      Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# 0           0       5    2010       WD           Normal     215000
# 1           0       6    2010       WD           Normal     105000
# ...       ...     ...     ...       ...             ...        ...
# 2928        0       4    2006       WD           Normal     170000
# 2929        0      11    2006       WD           Normal     188000
#
# [2930 rows x 82 columns]

# %% [markdown]
# ## Performance Metrics for Regression Models
#
# To evaluate the performance of a regression model, we compare the predicted labels from the model against the true labels. Since the labels are quantitative, it makes sense to look at the difference between each predicted label $\hat y_i$ and the true label $y_i$.
#
# One way to make sense of these differences is to square each difference and average the squared differences. This measure of error is known as **mean squared error** (or **MSE**, for short):
#
# $$
# \begin{align*}
# \textrm{MSE} &= \textrm{mean of } (y_i - \hat y_i)^2.
# \end{align*}
# $$
#
# MSE is difficult to interpret because its units are the square of the units of $y$. To make MSE more interpretable, it is common to take the _square root_ of the MSE to obtain the **root mean squared error** (or RMSE, for short):
#
# $$
# \begin{align*}
# \textrm{RMSE} &= \sqrt{\textrm{MSE}}.
# \end{align*}
# $$
#
# The RMSE measures how off a "typical" prediction is. Notice that the reasoning above is exactly the same reasoning that we used in the early labs when we defined the variance and the standard deviation.
#
# Another common measure of error is the **mean absolute error** (or **MAE**, for short):
#
# $$
# \begin{align*}
# \textrm{MAE} &= \textrm{mean of } |y_i - \hat y_i|.
# \end{align*}
# $$
#
# Like the RMSE, the MAE measures how off a "typical" prediction is. There are other metrics that can be used to measure the quality of a regression model, but these are the most common ones.

# %% [markdown]
# ## Training Error
#
# To calculate the MSE, RMSE, or MAE, we need data where the true labels are known. Where do we find such data? One natural source of labeled data is the training data, since we needed the true labels to be able to train a model.
#
# For a $k$-nearest neighbors model, the training data is the data from which the $k$-nearest neighbors are selected. So to calculate the training RMSE, we do the following:
#
# For each observation in the training data:
# 1. Find its $k$-nearest neighbors in the training data.
# 2. Average the labels of the $k$-nearest neighbors to obtain the predicted label.
# 3. Subtract the predicted label from the true label.
#
# At this point, we can average the square of these differences to obtain the MSE or average their absolute values to obtain the MAE.
#
# Let's calculate the training MSE for a 10-nearest neighbors model for house price using a subset of features from the Ames housing data set. First, we extract the variables that we need.

# %%
# Features in our model. All quantitative, except Neighborhood.
features = ["Lot Area", "Gr Liv Area",
            "Full Bath", "Half Bath",
            "Bedroom AbvGr", 
            "Year Built", "Yr Sold",
            "Neighborhood"]

X_train_dict = housing[features].to_dict(orient="records")
y_train = housing["SalePrice"]

# %% [markdown]
# Now we will use Scikit-Learn to preprocess the features...

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import StandardScaler

vec = DictVectorizer(sparse=False)
vec.fit(X_train_dict)
X_train = vec.transform(X_train_dict)

scaler = StandardScaler()
scaler.fit(X_train)
X_train_sc = scaler.transform(X_train)

# %% [markdown]
# ...and to fit the $k$-nearest neighbors model to the data.

# %%
from sklearn.neighbors import KNeighborsRegressor

# Fit a 10-nearest neighbors model.
model = KNeighborsRegressor(n_neighbors=10)
model.fit(X_train_sc, y_train)

# Calculate the model predictions on the training data.
y_train_pred = model.predict(X_train_sc)
y_train_pred
# Out:
# array([164090. , 131512.5, 154860. , ..., 128530. , 140600. , 201800. ])

# %% [markdown]
# Now it's time to compare these predictions to the true labels, which we know, since this is the training data.

# %%
# Calculate the mean-squared error.
mse = ((y_train - y_train_pred) ** 2).mean()
mse
# Out:
# 1139920438.2806828

# %% [markdown]
# This number is very large and not very interpretable (because it is in units of "dollars squared"). Let's take the square root to obtain the RMSE.

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 33762.70780433173

# %% [markdown]
# The RMSE says that our model's predictions are, on average, off by about \\$33,000. This is not great, but it is also not too bad when an average house is worth about \\$180,000.

# %% [markdown]
# ## The Problem with Training Error
#
# Training error is not a great measure of the quality of a model. To see why, consider a 1-nearest neighbor regression model. Before you read on, can you guess what the training error of a 1-nearest neighbor regression model will be?

# %%
# Fit a 1-nearest neighbors model.
model = KNeighborsRegressor(n_neighbors=1)
model.fit(X_train_sc, y_train)

# Calculate the model predictions on the training data.
y_train_pred = model.predict(X_train_sc)

# Calculate the MAE
(y_train - y_train_pred).abs().mean()
# Out:
# 57.846416382252556

# %% [markdown]
# The training error of this model seems too good to be true. Can our model really be off by just \$57.85 on average?
#
# The error is so small because the nearest neighbor to any observation in the training data will be the observation itself! In fact, if we look at the vector of differences between the true and predicted labels, we see that most of the differences are zero.

# %%
y_train - y_train_pred
# Out:
# 0       0.0
# 1       0.0
#        ...
# 2928    0.0
# 2929    0.0
# Name: SalePrice, Length: 2930, dtype: float64

# %% [markdown]
# Why isn't the MSE exactly equal to 0, then? That is because there may be multiple houses in the training data with the exact same values for all of the features, so there may be multiple observations that are a distance of 0.0 away. Any one of these observations has equal claim to being the "1-nearest neighbor". If we happen to select one of the _other_ houses in the training data as the nearest neighbor, then its price will in general be different.
#
# How many predictions did the 1-nearest neighbor model get wrong?

# %%
(y_train != y_train_pred).sum()
# Out:
# 22

# %% [markdown]
# The 1-nearest neighbor model nailed the price exactly for all but 22 of the 2930 houses, so the training error is small.
#
# Of course, a 1-nearest neighbor is unlikely to be the best model for predicting house prices. If one house in the training data happened to cost \\$10,000,000, it would not be sensible to predict another house to cost \\$10,000,000 -- even one very similar to it. This is why we usually average over multiple neighbors (i.e., $k$ neighbors) to make predictions.
#
# In the next section, we will learn a better way to measure the quality of a model than training error.

# %% [markdown]
# # Exercises

# %% [markdown]
# **Exercise 1.** Using the Tips data set (`./data/tips.csv`), train $k$-nearest neighbors regression models to predict the tip for different values of $k$. Calculate the training MAE of each model and make a plot showing this training error as a function of $k$.

# %%
tips_df = pd.read_csv("./data/tips.csv")
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
features = ["total_bill",
            "sex", "smoker",
            "day", 
            "time", "size"]

x_tips_dict = tips_df[features].to_dict(orient="records")
y_tips = tips_df["tip"]
x_tips_dict
# Out:
# [{'total_bill': 16.99,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 10.34,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 21.01,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 23.68,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 24.59,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 25.29,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 8.77,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 26.88,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 15.04,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 14.78,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 10.27,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 35.26,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 15.42,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 18.43,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 14.83,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 21.58,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 10.33,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 16.29,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 16.97,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 20.65,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 17.92,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 20.29,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 15.77,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 39.42,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 19.82,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 17.81,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 13.37,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 12.69,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 21.7,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 19.65,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 9.55,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 18.35,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 15.06,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 20.69,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 17.78,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 24.06,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 16.31,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 16.93,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 18.69,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 31.27,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 16.04,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 17.46,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 13.94,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 9.68,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 30.4,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 18.29,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 22.23,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 32.4,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 28.55,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 18.04,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 12.54,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 10.29,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 34.81,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 9.94,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 25.56,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 19.49,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 38.01,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 26.41,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 11.24,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 48.27,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 20.29,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 13.81,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 11.02,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 18.29,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 17.59,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 20.08,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 16.45,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 3.07,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 1},
#  {'total_bill': 20.23,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 15.01,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 12.02,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 17.07,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 26.86,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 25.28,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 14.73,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 10.51,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 17.92,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 27.2,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 4},
#  {'total_bill': 22.76,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 17.29,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 19.44,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 16.66,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 10.07,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 1},
#  {'total_bill': 32.68,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 15.98,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 34.83,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 4},
#  {'total_bill': 13.03,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 18.28,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 24.71,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 21.16,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 28.97,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Fri',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 22.49,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Fri',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 5.75,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Fri',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 16.32,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Fri',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 22.75,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Fri',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 40.17,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Fri',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 27.28,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Fri',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 12.03,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Fri',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 21.01,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Fri',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 12.46,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Fri',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 11.35,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Fri',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 15.38,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Fri',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 44.3,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 22.42,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 20.92,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 15.36,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 20.49,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 25.21,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 18.24,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 14.31,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 14.0,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 7.25,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 1},
#  {'total_bill': 38.07,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 23.95,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 25.71,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 17.31,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 29.93,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 10.65,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 12.43,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 24.08,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 4},
#  {'total_bill': 11.69,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 13.42,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 14.26,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 15.95,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 12.48,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 29.8,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 6},
#  {'total_bill': 8.52,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 14.52,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 11.38,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 22.82,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 3},
#  {'total_bill': 19.08,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 20.27,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 11.17,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 12.26,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 18.26,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 8.51,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 10.33,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 14.15,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 16.0,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 13.16,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 17.47,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 34.3,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 6},
#  {'total_bill': 41.19,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 5},
#  {'total_bill': 27.05,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 6},
#  {'total_bill': 16.43,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 8.35,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 18.64,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 3},
#  {'total_bill': 11.87,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 9.78,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 7.51,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 14.07,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 13.13,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 17.26,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 24.55,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 19.77,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 29.85,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 5},
#  {'total_bill': 48.17,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 6},
#  {'total_bill': 25.0,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 13.39,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 16.49,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 21.5,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 12.66,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 16.21,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 13.81,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 17.51,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 24.52,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 20.76,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 31.71,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 10.59,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 10.63,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 50.81,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 15.81,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 7.25,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 31.85,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 16.82,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 32.9,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 17.89,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 14.48,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 9.6,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 34.63,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 34.65,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 23.33,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 45.35,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 23.17,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 40.55,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 20.69,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 5},
#  {'total_bill': 20.9,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 30.46,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 5},
#  {'total_bill': 18.15,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 23.1,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 15.69,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sun',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 19.81,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 28.44,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 15.48,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 16.58,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 7.56,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 10.34,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 43.11,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 4},
#  {'total_bill': 13.0,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 13.51,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 18.71,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 3},
#  {'total_bill': 12.74,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 13.0,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 16.4,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 20.53,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 4},
#  {'total_bill': 16.47,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Thur',
#   'time': 'Lunch',
#   'size': 3},
#  {'total_bill': 26.59,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 38.73,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 24.27,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 12.76,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 30.06,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 25.89,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 48.33,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 13.27,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 28.17,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 12.9,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 28.15,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 5},
#  {'total_bill': 11.59,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 7.74,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 30.14,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 12.16,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Fri',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 13.42,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Fri',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 8.58,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Fri',
#   'time': 'Lunch',
#   'size': 1},
#  {'total_bill': 15.98,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Fri',
#   'time': 'Lunch',
#   'size': 3},
#  {'total_bill': 13.42,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Fri',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 16.27,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Fri',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 10.09,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Fri',
#   'time': 'Lunch',
#   'size': 2},
#  {'total_bill': 20.45,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 13.28,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 22.12,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 24.01,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 4},
#  {'total_bill': 15.69,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 11.61,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 10.77,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 15.53,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 10.07,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 12.6,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 32.83,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 35.83,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 29.03,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 3},
#  {'total_bill': 27.18,
#   'sex': 'Female',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 22.67,
#   'sex': 'Male',
#   'smoker': 'Yes',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 17.82,
#   'sex': 'Male',
#   'smoker': 'No',
#   'day': 'Sat',
#   'time': 'Dinner',
#   'size': 2},
#  {'total_bill': 18.78,
#   'sex': 'Female',
#   'smoker': 'No',
#   'day': 'Thur',
#   'time': 'Dinner',
#   'size': 2}]

# %%
vector = DictVectorizer(sparse=False)
vector.fit(x_tips_dict)
X_tips = vector.transform(x_tips_dict)

scaler = StandardScaler()
scaler.fit(X_tips)
X_tips_sc = scaler.transform(X_tips)
X_tips_sc
# Out:
# array([[-0.29059326, -0.74440589,  1.48678388, ...,  0.62158156,
#         -0.62158156, -0.31471131],
#        [-0.29059326, -0.74440589,  1.48678388, ...,  0.62158156,
#         -0.62158156, -1.06323531],
#        [-0.29059326, -0.74440589,  1.48678388, ...,  0.62158156,
#         -0.62158156,  0.1377799 ],
#        ...,
#        [-0.29059326,  1.34335316, -0.67259271, ...,  0.62158156,
#         -0.62158156,  0.3246295 ],
#        [-0.29059326,  1.34335316, -0.67259271, ...,  0.62158156,
#         -0.62158156, -0.2212865 ],
#        [-0.29059326, -0.74440589, -0.67259271, ...,  0.62158156,
#         -0.62158156, -0.1132289 ]])

# %%
tip_model = KNeighborsRegressor(n_neighbors=100)
tip_model.fit(X_tips_sc, y_tips)

# Calculate the model predictions on the training data.
y_tip_pred_100 = tip_model.predict(X_tips_sc)
y_tip_pred_100
# Out:
# array([2.9684, 3.0929, 3.1337, 3.1176, 3.3011, 3.285 , 2.9545, 3.285 ,
#        2.9966, 2.9966, 2.9545, 3.3917, 2.9966, 3.1537, 2.8963, 3.1273,
#        2.8892, 3.1337, 3.0652, 2.9584, 2.7397, 2.8755, 2.7288, 3.404 ,
#        2.7397, 3.071 , 2.7364, 2.7364, 2.8399, 2.8755, 2.7364, 3.0977,
#        2.68  , 3.2487, 2.7397, 3.0632, 2.7966, 2.8982, 2.7966, 3.184 ,
#        2.7966, 3.0789, 2.985 , 2.9545, 3.3159, 3.0794, 3.1273, 3.3223,
#        3.1172, 3.0789, 2.9701, 2.8287, 3.3917, 2.9545, 3.285 , 3.0892,
#        3.3281, 2.9603, 2.7716, 3.4738, 3.0282, 2.7691, 2.7716, 3.0621,
#        2.7966, 2.9623, 2.7636, 2.6927, 2.7397, 2.8832, 2.7364, 2.8982,
#        2.9637, 2.9676, 2.68  , 2.7364, 2.9369, 3.0661, 2.7764, 2.5795,
#        2.7337, 2.5764, 2.4962, 2.8382, 2.5764, 3.1608, 2.5575, 2.6157,
#        2.7904, 2.7096, 3.1353, 2.9723, 2.741 , 2.8041, 2.9414, 3.3989,
#        3.1176, 2.6629, 2.8798, 2.714 , 2.8061, 2.8041, 3.3327, 2.8218,
#        2.8904, 2.894 , 3.0282, 3.0294, 2.7397, 2.7134, 2.7364, 2.6113,
#        3.3174, 3.1176, 3.2122, 2.9684, 3.3159, 2.5935, 2.6632, 2.8946,
#        2.5715, 2.6632, 2.574 , 2.5764, 2.6632, 3.2689, 2.522 , 2.6793,
#        2.6257, 2.9191, 2.6656, 2.8471, 2.5935, 2.6479, 2.8241, 2.6135,
#        2.5935, 2.6793, 2.7326, 2.6632, 2.7957, 3.3277, 3.2816, 3.1507,
#        2.7349, 2.6135, 2.8589, 2.6404, 2.522 , 2.522 , 3.005 , 2.9712,
#        3.1337, 3.19  , 3.1537, 3.3891, 3.6119, 3.2863, 2.8963, 3.1537,
#        3.1537, 2.9701, 3.0546, 2.985 , 2.9257, 3.1337, 3.0921, 3.3223,
#        2.6975, 2.6975, 3.3845, 2.899 , 2.707 , 3.1975, 2.963 , 3.1975,
#        2.9833, 2.9292, 2.7859, 3.2274, 3.5057, 3.019 , 3.5794, 3.0686,
#        3.2676, 3.3024, 3.0625, 3.5529, 3.062 , 3.0834, 2.9539, 2.7314,
#        2.7419, 2.7299, 2.7326, 2.522 , 2.6174, 3.1643, 2.6107, 2.6971,
#        2.7739, 2.5943, 2.6107, 2.6806, 2.8129, 2.7526, 3.1648, 3.3634,
#        3.0294, 2.6975, 3.2379, 3.2309, 3.4738, 2.6975, 3.1291, 2.6975,
#        3.3164, 2.7716, 2.7269, 3.315 , 2.6961, 2.5672, 2.5378, 2.7173,
#        2.7066, 2.7017, 2.5317, 3.1115, 2.7364, 2.8052, 3.1909, 2.9988,
#        2.7364, 2.7364, 2.899 , 2.7364, 2.7716, 3.1763, 3.2892, 3.104 ,
#        2.9637, 3.0263, 2.7397, 2.7184])

# %%
mse100 = ((y_tips - y_tip_pred_100) ** 2).mean()
mse100
# Out:
# 1.59133106352459

# %%
tip_model = KNeighborsRegressor(n_neighbors=10)
tip_model.fit(X_tips_sc, y_tips)

# Calculate the model predictions on the training data.
y_tip_pred_10 = tip_model.predict(X_tips_sc)
y_tip_pred_10

mse10 = ((y_tips - y_tip_pred_10) ** 2).mean()
mse10
# Out:
# 1.086856032786885

# %%
tip_model = KNeighborsRegressor(n_neighbors=200)
tip_model.fit(X_tips_sc, y_tips)

# Calculate the model predictions on the training data.
y_tip_pred_200 = tip_model.predict(X_tips_sc)
y_tip_pred_200

mse200 = ((y_tips - y_tip_pred_200) ** 2).mean()
mse200
# Out:
# 1.7338979557889345

# %%
tip_model = KNeighborsRegressor(n_neighbors=244)
tip_model.fit(X_tips_sc, y_tips)

# Calculate the model predictions on the training data.
y_tip_pred_244 = tip_model.predict(X_tips_sc)
y_tip_pred_244

mse244 = ((y_tips - y_tip_pred_500) ** 2).mean()
mse244
# Out:
# 1.9066085124966412

# %%
data = {'mse':[1.086856032786885, 1.59133106352459, 1.7338979557889345, 1.9066085124966412], 'K value':[10, 100, 200, 244]}
df = pd.DataFrame(data)
df.plot.line(x = 'mse', y = 'K value')

# %% [markdown]
# # Part 2: Test and Validation Errors
#
# In the previous section, we saw that training error is not a great measure of a model's quality. For example, a $1$-nearest neighbor model will have a training error of $0.0$ (or close to it), but it is not necessarily the best prediction model, especially if there are outliers in the training data.
#
# In order to come up with a better measure of model quality, we need to formalize what it is we want to measure.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
pd.options.display.max_rows = 5

housing = pd.read_csv("./data/ames.tsv", sep="\t")
housing
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
#      Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0      NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1      NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# ...    ...       ...          ...  ...       ...     ...    ...          ...
# 2928   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 2929   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
#
#      Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# 0           0       5    2010       WD           Normal     215000
# 1           0       6    2010       WD           Normal     105000
# ...       ...     ...     ...       ...             ...        ...
# 2928        0       4    2006       WD           Normal     170000
# 2929        0      11    2006       WD           Normal     188000
#
# [2930 rows x 82 columns]

# %% [markdown]
# ## Overfitting and Test Error
#
# Ultimately, the goal of any prediction model is to make predictions on _future_ data. Therein lies the problem with training error. Training error measures how well a model predicts on the current data. It is possible to build a model that **overfits** to the training data---that is, a model that fits so well to the current data that it does poorly on future data.
#
# For example, consider fitting two different models to the 10 training observations shown below. The model represented by the red line actually passes through every observation (that is, its training error is zero). However, most people would prefer the model represented by the blue line. If one had to make a prediction for $y$ when $x = 0.8$, the value of the blue line is intuitively more plausible than the value of the red line, which is out of step with the nearby points.
#
# ![](./images/overfitting.png)
#
# The argument for the blue model depends on _future_ data because the blue model is actually worse than the red model on the current data. The red model tries so hard to get the predictions on the training data right that it ends up _overfitting_.
#
# If the goal is to build a model that performs well on future data, then we ought to evaluate it (i.e., by calculating MSE, MAE, etc.) on future data. The prediction error on future data is also known as **test error**, in contrast to training error, which is the prediction error on current data. To calculate the test error, we need _labeled_ future data. In many applications, future data is expensive to collect and _labeled_ future data is even more expensive. How can we approximate the test error, using just the data that we have?

# %% [markdown]
# ## Validation Error
#
# The solution is to split the training data into a **training set** and a **validation set**. The model will only be fit on the observations of the training set. Then, the model will be evaluated on the validation set. Because the validation set has not been seen by the model already, it essentially plays the role of "future" data, even though it was carved out of the current data.
#
# The prediction error on the validation set is known as the **validation error**. The validation error is an approximation to the test error.

# %% [markdown]
# To split our data into training and validation sets, we use the `.sample()` function in `pandas`. Let's use this to split our data into two equal halves, which we will call `train` and `val`.

# %%
train = housing.sample(frac=.5)
val = housing.drop(train.index)

train
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1979   1980  902125120           30        RM          60.0     10800   Pave
# 2257   2258  916326040           20        RL         115.0     16905   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 487     488  528290120           60        RL          60.0      8123   Pave
# 2099   2100  906378150           20        RL          93.0     10481   Pave
#
#      Alley Lot Shape Land Contour  ... Pool Area Pool QC Fence Misc Feature  \
# 1979  Grvl       Reg          Lvl  ...         0     NaN   NaN         Shed
# 2257   NaN       Reg          Lvl  ...         0     NaN   NaN          NaN
# ...    ...       ...          ...  ...       ...     ...   ...          ...
# 487    NaN       IR1          Lvl  ...         0     NaN   NaN          NaN
# 2099   NaN       IR1          Lvl  ...         0     NaN   NaN          NaN
#
#      Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# 1979      450       8    2007       WD           Normal     100000
# 2257        0       7    2007       WD           Normal     170000
# ...       ...     ...     ...       ...             ...        ...
# 487         0       6    2009       WD           Normal     179000
# 2099        0       6    2007       New         Partial     360000
#
# [1465 rows x 82 columns]

# %% [markdown]
# Now let's use this training/validation split to approximate the test error of a 10-nearest neighbors model.
#
# First, we extract the variables we need.

# %%
# Features in our model. All quantitative, except Neighborhood.
features = ["Lot Area", "Gr Liv Area",
            "Full Bath", "Half Bath",
            "Bedroom AbvGr", 
            "Year Built", "Yr Sold",
            "Neighborhood"]

X_train_dict = train[features].to_dict(orient="records")
X_val_dict = val[features].to_dict(orient="records")

y_train = train["SalePrice"]
y_val = val["SalePrice"]

# %% [markdown]
# Next, we use Scikit-Learn to preprocess the training and the validation data. Note that the vectorizer and the scaler are both fit to the training data, so we learn the categories, the mean, and standard deviation from the training set---and use these to transform both the training and validation sets.

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import StandardScaler

# convert categorical variables to dummy variables
vec = DictVectorizer(sparse=False)
vec.fit(X_train_dict)
X_train = vec.transform(X_train_dict)
X_val = vec.transform(X_val_dict)

# standardize the data
scaler = StandardScaler()
scaler.fit(X_train)
X_train_sc = scaler.transform(X_train)
X_val_sc = scaler.transform(X_val)

# %% [markdown]
# We are now ready to fit a $k$-nearest neighbors model to the training data.

# %%
from sklearn.neighbors import KNeighborsRegressor

# Fit a 10-nearest neighbors model.
model = KNeighborsRegressor(n_neighbors=10)
model.fit(X_train_sc, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                     weights='uniform')

# %% [markdown]
# We make predictions on the validation set and calculate the validation RMSE:

# %%
y_val_pred = model.predict(X_val_sc)
rmse = np.sqrt(((y_val - y_val_pred) ** 2).mean())
rmse
# Out:
# 44153.090411251666

# %% [markdown]
# Notice that the test error is higher than the training error that we calculated in the previous section. In general, this will be true. It is harder for a model to predict for new observations it has not seen, than for observations it has seen!

# %% [markdown]
# ## Cross Validation
#
# One downside of the validation error above is that it was calculated using only 50% of the data. As a result, the estimate is noisy.
#
# There is a cheap way to obtain a second opinion of how well our model will do on future data. Previously, we split our data at random into two halves, training the model on the first half and evaluating it using the second half. Because the model has not already seen the second half of the data, this approximates how well the model would perform on future data.
#
# But the way we split our data was arbitrary. We might as well swap the roles of the two halves, training the model on the _second_ half and evaluating it using the _first_ half. As long as the model is always evaluated on data that is different from the data that was used to train it, we have a valid measure of how well our model would perform on future data. A schematic of this approach, known as **cross-validation**, is shown below.
#
# <img src="./images/cross-validation.png" />
#
# Because we will be doing all computations twice, just with different data, let's wrap the $k$-nearest neighbors algorithm above into a function called `get_val_error()`, that computes the validation error given training and validation data.

# %%
def get_val_error(X_train, y_train, X_val, y_val):
    
    # convert categorical variables to dummy variables
    vec = DictVectorizer(sparse=False)
    vec.fit(X_train_dict)
    X_train = vec.transform(X_train_dict)
    X_val = vec.transform(X_val_dict)

    # standardize the data
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train_sc = scaler.transform(X_train)
    X_val_sc = scaler.transform(X_val)
    
    # Fit a 10-nearest neighbors model.
    model = KNeighborsRegressor(n_neighbors=10)
    model.fit(X_train_sc, y_train)
    
    # Make predictions on the validation set.
    y_val_pred = model.predict(X_val_sc)
    rmse = np.sqrt(((y_val - y_val_pred) ** 2).mean())
    
    return rmse

# %%
y_val.size
# Out:
# 1465

# %% [markdown]
# If we apply this function to the training and test sets from earlier, we get the same estimate of the test error.

# %%
val_error_10=get_val_error(X_train, y_train, X_val, y_val)

# %% [markdown]
# But if we reverse the roles of the training and test sets, we get another estimate of the test error.

# %%
other_val_error_10=get_val_error(X_val, y_val, X_train, y_train)

# %% [markdown]
# Now we have two, somewhat independent estimates of the test error. It is common to average the two to obtain an overall estimate of the test error, called the **cross-validation error**. Notice that the cross-validation error uses each observation in the data exactly once. We make a prediction for each observation, but always using a model that was trained on data that does not include that observation.

# %% [markdown]
# # Part 2: Exercises

# %% [markdown]
# **Exercise 2.** Use cross-validation to estimate the test error of a 1-nearest neighbor classifier on the Ames housing price data. How does a 1-nearest neighbor classifier compare to a 10-nearest neighbor classifier in terms of its ability to predict on _future_ data?

# %%
def get_val_error_10(X_train, y_train, X_val, y_val):
    
    # convert categorical variables to dummy variables
    vec = DictVectorizer(sparse=False)
    vec.fit(X_train_dict)
    X_train = vec.transform(X_train_dict)
    X_val = vec.transform(X_val_dict)

    # standardize the data
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train_sc = scaler.transform(X_train)
    X_val_sc = scaler.transform(X_val)
    
    # Fit a 10-nearest neighbors model.
    model = KNeighborsRegressor(n_neighbors=10)
    model.fit(X_train_sc, y_train)
    
    # Make predictions on the validation set.
    y_val_pred = model.predict(X_val_sc)
    rmse = np.sqrt(((y_val - y_val_pred) ** 2).mean())
    
    return rmse

val_error_1=get_val_error_1(X_train, y_train, X_val, y_val)
X_train.size , y_train.size, X_val.size, y_val.size
# Out:
# (48345, 1465, 48345, 1465)

# %%
other_vale_error_1=get_val_error_1(X_val, y_val, X_train, y_train)

# %%
true_error_1 = (val_error_1 +other_vale_error_1) / 2
true_error_1
# Out:
# 80751.2567563622

# %%
true_error_10 = (val_error_10 + other_val_error_10)/2
true_error_10
# Out:
# 63264.559415788215

# %% [markdown]
# #### The test error for 1 nearest neighbor is lower than the test error for 10 nearest neighbors

# %% [markdown]
# **Exercise 3.** Using the Tips data set (`./data/tips.csv`), train $k$-nearest neighbors regression models to predict the tip for different values of $k$. Calculate the training and validation MAE of each model, and make a plot showing these errors as a function of $k$.

# %%
tip_train = tips_df.sample(frac=.5)
tip_val = tips_df.drop(tip_train.index)

tip_train
tip_val
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [122 rows x 7 columns]

# %%
features = ["total_bill",
            "sex", "smoker",
            "day", 
            "time", "size"]

train_tips_dict = tip_train[features].to_dict(orient="records")
val_tips_dict = tip_val[features].to_dict(orient="records")

y_train_tips = tip_train["tip"]
y_val_tips = tip_val["tip"]

# %%
# convert categorical variables to dummy variables
vec = DictVectorizer(sparse=False)
vec.fit(train_tips_dict)
tips_train = vec.transform(train_tips_dict)
tips_val = vec.transform(val_tips_dict)


# standardize the data
scaler = StandardScaler()
scaler.fit(tips_train)
tip_train_sc = scaler.transform(tips_train)
tip_val_sc = scaler.transform(tips_train)

# %%
model = KNeighborsRegressor(n_neighbors=10)
model.fit(tip_train_sc, y_train_tips)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                     weights='uniform')

# %%
y_val_pred_tips = model.predict(tip_train_sc)
rmse = np.sqrt(((y_val_tips - y_val_pred_tips) ** 2).mean())
rmse
# Out:
# 1.5381448561044748

# %%
def get_val_error_tips(X_train, y_train, X_val, y_val, n_val):
    
    # convert categorical variables to dummy variables
    vect = DictVectorizer(sparse=False)
    vect.fit(train_tips_dict)
    X_trains = vect.transform(train_tips_dict)
    X_vals = vect.transform(val_tips_dict)

    # standardize the data
    scalers = StandardScaler()
    scalers.fit(X_train)
    X_train_scs = scaler.transform(X_train)
    X_val_scs = scaler.transform(X_val)
    
    # Fit a 10-nearest neighbors model.
    modelss = KNeighborsRegressor(n_neighbors=n_val)
    modelss.fit(X_train_scs, y_train)
    
    # Make predictions on the validation set.
    y_val_preds = modelss.predict(X_val_scs)
    n_rmse = np.sqrt(((y_val - y_val_preds) ** 2).mean())
    
    return n_rmse

# %%
(get_val_error_tips(tips_train, y_train_tips, tips_val, y_val_tips,1) + 
 get_val_error_tips(tips_val,y_val_tips,tips_train,y_train_tips,1))/2
# Out:
# 1.3369329265332306

# %%
(get_val_error_tips(tips_train, y_train_tips, tips_val, y_val_tips,10) + 
 get_val_error_tips(tips_val,y_val_tips,tips_train,y_train_tips,10))/2
# Out:
# 1.1668496992417912

# %%
(get_val_error_tips(tips_train, y_train_tips, tips_val, y_val_tips,100) + 
 get_val_error_tips(tips_val,y_val_tips,tips_train,y_train_tips,100))/2
# Out:
# 1.312639653876727

# %%
(get_val_error_tips(tips_train, y_train_tips, tips_val, y_val_tips,122) + 
 get_val_error_tips(tips_val,y_val_tips,tips_train,y_train_tips,122))/2
# Out:
# 1.3809427804292325

# %%
ndata = {'training and validation MAE':[1.3369329265332306, 1.1668496992417912, 1.312639653876727, 1.3809427804292325], 'K value':[1, 10, 100, 122]}
ndf = pd.DataFrame(ndata)
ndf.plot.line(x = 'training and validation MAE', y = 'K value')

# %% [markdown]
# # Part 3: Bringing It All Together: Model Selection and Hyperparameter Tuning
#
# This section will use the tools developed in the previous section to answer two important questions:
#
# - Model Selection: How do we determine which model is best?
# - Hyperparameter Tuning: How do we choose hyperparameters, such as $k$ in $k$-nearest neighbors?
#
# In the previous section, we saw how to use training and validation sets to estimate how well the model will perform on future data. A natural way to decide between competing models (or hyperparameters) is to choose the one that minimizes the validation error.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
pd.options.display.max_rows = 5

housing = pd.read_csv("./data/ames.tsv", sep="\t")
housing
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
#      Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0      NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1      NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# ...    ...       ...          ...  ...       ...     ...    ...          ...
# 2928   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 2929   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
#
#      Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# 0           0       5    2010       WD           Normal     215000
# 1           0       6    2010       WD           Normal     105000
# ...       ...     ...     ...       ...             ...        ...
# 2928        0       4    2006       WD           Normal     170000
# 2929        0      11    2006       WD           Normal     188000
#
# [2930 rows x 82 columns]

# %% [markdown]
# ## $K$-Fold Cross Validation
#
# Previously, we carried out cross validation by splitting the data into 2 halves, alternately using one half to train the model and the other to evaluate the model. In general, we can split the data into $k$ subsamples, alternately training the data on $k-1$ subsamples and evaluating the model on the $1$ remaining subsample, i.e., the validation set. This produces $k$ somewhat independent estimates of the test error. This procedure is known as **$k$-fold cross validation**. (Be careful not to confuse the $k$ in $k$-fold cross validation with the $k$ in $k$-nearest neighbors.) Therefore, the specific version of cross validation that we saw earlier is $2$-fold cross validation.
#
# A schematic of $4$-fold cross validation is shown below.
#
# ![](./images/k-folds.png)
#
# Implementing $k$-fold cross validation from scratch for $k > 2$ is straightforward but messy, so we will usually let Scikit-Learn do it for us.

# %% [markdown]
# ## Cross Validation in Scikit-Learn
#
# Scikit-Learn provides a function, `cross_val_score`, that will carry out all aspects of $k$-fold cross validation:
#
# 1. split the data into $k$ subsamples
# 2. combine the first $k-1$ subsamples into a training set and train the model
# 3. evaluate the model predictions on the last ($k$th) held-out subsample
# 4. repeat steps 2-3 $k$ times (i.e. $k$ "folds"), each time holding out a different one of the $k$ subsamples
# 4. calculate $k$ "scores", one from each validation set
#
# There is one subtlety to keep in mind. Training a $k$-nearest neighbors model is not just about fitting the model; it also involves dummifying the categorical variables and scaling the variables. These preprocessing steps should be included in the cross-validation process. They cannot be done ahead of time.
#
# For example, suppose we run $5$-fold cross validation. Then:
#
# - When subsamples 1-4 are used for training and subsample 5 for validation, the observations have to be standardized with respect to the mean and SD of subsamples 1-4.
# - When subsamples 2-5 are used for training and subsample 1 for validation, the observations have to be standardized with respect to the mean and SD of subsamples 2-5.
# - And so on.
#
# We cannot simply standardize all of the data once at the beginning and run cross validation on the standardized data. To do so would be allowing the model to peek at the validation set during training. That's because each training set would be standardized with respect to a mean and SD that is calculated from all data, including the validation set. To be completely above board, we should standardize each training set with respect to the mean and SD of just that training set.
#
# Fortunately, Scikit-Learn provides a `Pipeline` object that allows us to chain these preprocessing steps together with the model we want to fit.

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import Pipeline

# get the features (in dict format) and the labels
# (do not split into training and validation sets)
features = ["Lot Area", "Gr Liv Area",
            "Full Bath", "Half Bath",
            "Bedroom AbvGr", 
            "Year Built", "Yr Sold",
            "Neighborhood"]
X_dict = housing[features].to_dict(orient="records")
y = housing["SalePrice"]

# specify the pipeline
vec = DictVectorizer(sparse=False)
scaler = StandardScaler()
model = KNeighborsRegressor(n_neighbors=10)
pipeline = Pipeline([("vectorizer", vec), ("scaler", scaler), ("fit", model)])

# %% [markdown]
# This entire `Pipeline` can be passed to `cross_val_score`, along with the data, the number of folds $k$ (`cv`), and the type of score (`scoring`). So $5$-fold cross validation in Scikit-Learn would look as follows:

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(pipeline, X_dict, y, 
                         cv=5, scoring="neg_mean_squared_error")
scores
# Out:
# array([-1.98025092e+09, -1.47950953e+09, -1.54632969e+09, -1.87662563e+09,
#        -1.42167566e+09])

# %% [markdown]
# Notice that we get five (negative) validation MSEs, one from each of the 5 folds. `cross_val_score` returns the _negative_ MSE, instead of the MSE, because by definition, a _higher_ score is better. (Since we want the MSE to be as _low_ as possible, we want the negative MSE to be as _high_ as possible.)
#
# To come up with a single overall estimate of the test MSE, we flip the signs and average the MSEs:

# %%
np.mean(-scores)
# Out:
# 1660878287.4356349

# %% [markdown]
# The RMSE is the square root of the MSE:

# %%
np.sqrt(np.mean(-scores))
# Out:
# 40753.874508267734

# %% [markdown]
# ## Hyperparameter Tuning
#
# How do we choose $k$? We can simply try all values of $k$ and pick the one with the smallest (test) MSE.

# %%
vec = DictVectorizer(sparse=False)
scaler = StandardScaler()

# calculates estimate of test error based on 10-fold cross validation
def get_cv_error(k):
    model = KNeighborsRegressor(n_neighbors=k)
    pipeline = Pipeline([("vectorizer", vec), ("scaler", scaler), ("fit", model)])
    mse = np.mean(-cross_val_score(
        pipeline, X_dict, y, 
        cv=10, scoring="neg_mean_squared_error"
    ))
    return mse
    
ks = pd.Series(range(1, 51))
ks.index = range(1, 51)
test_errs = ks.apply(get_cv_error)

test_errs.plot.line()
test_errs.sort_values()
# Out:
# 4     1.390511e+09
# 3     1.405909e+09
#           ...
# 49    2.208727e+09
# 50    2.216495e+09
# Length: 50, dtype: float64

# %% [markdown]
# The MSE is minimized near $k = 4$, which suggests that a $4$-nearest neighbors model is optimal for prediction.

# %% [markdown]
# ## Model Selection
#
# Suppose we are not sure whether `Yr Sold` should be included in the $4$-nearest neighbors model or not. To determine whether or not it should be included, we can fit a model with `Yr Sold` included and another model with it excluded, and see which model has the better (test) MSE.

# %%
vec = DictVectorizer(sparse=False)
scaler = StandardScaler()
model = KNeighborsRegressor(n_neighbors=4)
pipeline = Pipeline([("vectorizer", vec), ("scaler", scaler), ("fit", model)])

# %%
features = ["Lot Area", "Gr Liv Area",
            "Full Bath", "Half Bath",
            "Bedroom AbvGr", 
            "Year Built", "Yr Sold",
            "Neighborhood"]
X_dict = housing[features].to_dict(orient="records")
np.mean(
    -cross_val_score(pipeline, X_dict, y, cv=10, scoring="neg_mean_squared_error")
)
# Out:
# 1390511354.3758318

# %%
features = ["Lot Area", "Gr Liv Area",
            "Full Bath", "Half Bath",
            "Bedroom AbvGr", 
            "Year Built",
            "Neighborhood"]
X_dict = housing[features].to_dict(orient="records")
-cross_val_score(pipeline, X_dict, y, cv=10, scoring="neg_mean_squared_error").mean()

# %% [markdown]
# The MSE actually goes down when we remove `Yr Sold`, so it seems that the model is better off without this variable.

# %% [markdown]
# # Part 2: Exercises

# %% [markdown]
# **Exercise 4.** Using the Tips data set (`./data/tips.csv`), train $k$-nearest neighbors regression models to predict the tip for different values of $k$ and validate your model using 5 fold cross validation. Calculate the training and validation MAE of each model, and make a plot showing these errors as a function of $k$.

# %%
features = ["total_bill",
            "sex", "smoker",
            "day", 
            "time", "size"]
X_dict = tips_df[features].to_dict(orient="records")
y = tips_df["tip"]

# specify the pipeline
vec = DictVectorizer(sparse=False)
scaler = StandardScaler()
model = KNeighborsRegressor(n_neighbors=10)
pipeline = Pipeline([("vectorizer", vec), ("scaler", scaler), ("fit", model)])

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(pipeline, X_dict, y, 
                         cv=5, scoring="neg_mean_squared_error")
scores
# Out:
# array([-1.25718312, -1.32156371, -0.96711884, -1.93721169, -1.69369319])

# %%
np.mean(-scores)
# Out:
# 1.4353541109693877

# %%
np.sqrt(np.mean(-scores))
# Out:
# 1.1980626490168984

# %%
vec = DictVectorizer(sparse=False)
scaler = StandardScaler()

# calculates estimate of test error based on 10-fold cross validation
def get_cv_error(k):
    model = KNeighborsRegressor(n_neighbors=k)
    pipeline = Pipeline([("vectorizer", vec), ("scaler", scaler), ("fit", model)])
    mse = np.mean(-cross_val_score(
        pipeline, X_dict, y, 
        cv=10, scoring="neg_mean_squared_error"
    ))
    return mse
    
ks = pd.Series(range(1, 51))
ks.index = range(1, 51)
test_errs = ks.apply(get_cv_error)

test_errs.plot.line()
test_errs.sort_values()
# Out:
# 14    1.390168
# 13    1.400540
#         ...
# 2     1.571619
# 1     2.219054
# Length: 50, dtype: float64

# %% [markdown]
# What is the best value for k?
#
# **Answer Here:**
# MSE is minimzed at k = 13, suggesting that a 13-nearest neighbors model is the most optimal for this prediction

# %% [markdown]
# **BONUS BONUS BONUS 5 Points: Exercise 5.** Use what we've learned about model selection to determine whether or not including the day of the week is a good feature for a model to predict tips.

# %%
# YOUR CODE HERE

# %% [markdown]
# Should we include day of the week?
#
# **Answer Here:**
